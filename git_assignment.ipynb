# %%
hwk_num = "01"
proj_subpath = f"My Drive/active/m5364-6-data-science-20-21/student repos"
GIT = {"user_name": "scook4242", "email": "scook4242@gmail.com", "token": "a75a21b2a8414bc0bb4c98af0b195c0f3249e49e"}

from google.colab import drive
root_path = '/content/drive'
drive.mount(root_path)

hwk_name = f"data-science-20-21-hwk{hwk_num}"
proj_path = f"{root_path}/{proj_subpath}/"
repo_name = f"{hwk_name}-{GIT['user_name']}"
repo_path = proj_path + repo_name

repo_url = f"https://{GIT['token']}@github.com/Tarleton-Math/{repo_name}.git"
upstream_url = f"https://github.com/Tarleton-Math/{hwk_name}.git"

! git config --global user.name "{GIT['user_name']}"
! git config --global user.email "{GIT['email']}"
# %cd '{proj_path}'
! git clone "{repo_url}"
# %cd '{repo_path}'
! git pull
! git remote add upstream "{upstream_url}"
! git fetch upstream
! git merge upstream/master
